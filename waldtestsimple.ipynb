# %%
import statsmodels.api as sm
import numpy as np

# %%
import statsmodels.formula.api as smf

# %%
dat = sm.datasets.get_rdataset("Guerry", "HistData").data

# %%
dat
# Out:
#     dept Region    Department  Crime_pers  Crime_prop  Literacy  Donations  \
# 0      1      E           Ain       28870       15890        37       5098
# 1      2      N         Aisne       26226        5521        51       8901
# 2      3      C        Allier       26747        7925        13      10973
# 3      4      E  Basses-Alpes       12935        7289        46       2733
# 4      5      E  Hautes-Alpes       17488        8174        69       6962
# ..   ...    ...           ...         ...         ...       ...        ...
# 81    86      W        Vienne       15010        4710        25       8922
# 82    87      C  Haute-Vienne       16256        6402        13      13817
# 83    88      E        Vosges       18835        9044        62       4040
# 84    89      C         Yonne       18006        6516        47       4276
# 85   200    NaN         Corse        2199        4589        49      37015
#
#     Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 0     33120     35039    2:Med  ...             71           60
# 1     14572     12831    2:Med  ...              4           82
# 2     17044    114121    2:Med  ...             46           42
# 3     23018     14238     1:Sm  ...             70           12
# 4     23076     16171     1:Sm  ...             22           23
# ..      ...       ...      ...  ...            ...          ...
# 81    35224     21851    2:Med  ...             20            1
# 82    19940     33497    2:Med  ...             68            6
# 83    14978     33029    2:Med  ...             58           34
# 84    16616     12789    2:Med  ...             32           22
# 85    24743     37016    2:Med  ...             81            2
#
#     Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# 0                69       41         55           46           13   218.372
# 1                36       38         82           24          327    65.945
# 2                76       66         16           85           34   161.927
# 3                37       80         32           29            2   351.399
# 4                64       79         35            7            1   320.280
# ..              ...      ...        ...          ...          ...       ...
# 81               44       40         38           65           18   170.523
# 82               78       55         11           84            7   198.874
# 83                5       14         85           11           43   174.477
# 84               35       51         66           27          272    81.797
# 85               84       83          9           25            1   539.213
#
#     Area  Pop1831
# 0   5762   346.03
# 1   7369   513.00
# 2   7340   298.26
# 3   6925   155.90
# 4   5549   129.10
# ..   ...      ...
# 81  6990   282.73
# 82  5520   285.13
# 83  5874   397.99
# 84  7427   352.49
# 85  8680   195.41
#
# [86 rows x 23 columns]

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   dept             86 non-null     int64
#  1   Region           85 non-null     object
#  2   Department       86 non-null     object
#  3   Crime_pers       86 non-null     int64
#  4   Crime_prop       86 non-null     int64
#  5   Literacy         86 non-null     int64
#  6   Donations        86 non-null     int64
#  7   Infants          86 non-null     int64
#  8   Suicides         86 non-null     int64
#  9   MainCity         86 non-null     object
#  10  Wealth           86 non-null     int64
#  11  Commerce         86 non-null     int64
#  12  Clergy           86 non-null     int64
#  13  Crime_parents    86 non-null     int64
#  14  Infanticide      86 non-null     int64
#  15  Donation_clergy  86 non-null     int64
#  16  Lottery          86 non-null     int64
#  17  Desertion        86 non-null     int64
#  18  Instruction      86 non-null     int64
#  19  Prostitutes      86 non-null     int64
#  20  Distance         86 non-null     float64
#  21  Area             86 non-null     int64
#  22  Pop1831          86 non-null     float64
# dtypes: float64(2), int64(18), object(3)
# memory usage: 15.6+ KB

# %%
results = smf.ols('Lottery ~ Literacy +Donations+ np.log(Pop1831)', data=dat).fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     15.33
# Date:                Fri, 25 Mar 2022   Prob (F-statistic):           5.29e-08
# Time:                        18:28:23   Log-Likelihood:                -379.10
# No. Observations:                  86   AIC:                             766.2
# Df Residuals:                      82   BIC:                             776.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         242.3604     35.322      6.861      0.000     172.093     312.627
# Literacy           -0.4697      0.128     -3.660      0.000      -0.725      -0.214
# Donations           0.0004      0.000      1.176      0.243      -0.000       0.001
# np.log(Pop1831)   -31.2863      5.963     -5.247      0.000     -43.149     -19.424
# ==============================================================================
# Omnibus:                        3.907   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.142   Jarque-Bera (JB):                3.488
# Skew:                          -0.492   Prob(JB):                        0.175
# Kurtosis:                       3.076   Cond. No.                     1.49e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.49e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
waldtest=results.wald_test(r_matrix='Donations=0',use_f=True)
print(waldtest)
# Out:
# <F test: F=array([[1.38187113]]), p=0.2431845834152369, df_denom=82, df_num=1>

# %% [markdown]
#  If the p-value is less than 0.05, we reject the null hypothesis that there's no difference between the means and conclude that a significant difference does exist. If the p-value is larger than 0.05, we cannot conclude that a significant difference exists.
